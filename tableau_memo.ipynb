# %% [markdown]
# # Tableau Softwareの使い方についてのメモ
#
# ## あるフィールドのユニークな値の数の合計
#
# 1. 分析(A) > 計算フィールドの作成(C)を選ぶ
#
#     計算フィールドウィンドウが表示される
#
# 2. 名前に適当な名前を付ける（後にメジャーに表示されるようになる）
#
# 3. 関数(U)から**COUNTD**を選択し、引数にフィールドの名前を選択し、OKボタンを押下
#
#     メジャーに作成した計算フィールドが追加される
#
# 4. メジャーから作成した計算フィールドをDrag&Dropでシートに移すことでカウント値が表示されるようになる
#
# ## ワークシートの計算結果をデータソースとして再利用する方法
#
# 2014/06/02の時点で、この機能はまだ未実装のようだ
#
# http://community.tableausoftware.com/ideas/1604
#
# ## ビンを作成する上での前提条件
#
# Tableauでビン(bin)を作成するには、データソースがリレーショナル データソースである必要がある。多次元データソースからはビンが作成できない。
# 参考:
#   * http://kb.tableausoftware.com/articles/knowledgebase/functional-differences-olap-relational
#   * http://onlinehelp.tableausoftware.com/v8.1/pro/online/ja-jp/help.htm#calculations_bins.html%3FTocPath%3D%E9%AB%98%E5%BA%A6%E3%81%AA%E5%88%86%E6%9E%90%7C%E8%A8%88%E7%AE%97%20|_____4
